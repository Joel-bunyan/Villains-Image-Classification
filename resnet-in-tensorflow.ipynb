# %%
import numpy as np
import tensorflow as tf
import matplotlib.image as mpimg
import matplotlib.pyplot  as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(rescale=1.0 / 255)

images = datagen.flow_from_directory('/kaggle/input/villains-image-classification/Villains', target_size=(150,150),
            class_mode='sparse')
# Out:
# Found 100 images belonging to 5 classes.

# %%
resnet = tf.keras.applications.resnet50.ResNet50(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape=(150,150,3),
    pooling=None,
    classes=5,
    classifier_activation='softmax'
)
for layer in resnet.layers:
    layer.trainable = False
i = tf.keras.layers.Input(shape=(150,150,3))
x1 = resnet(i)

x5 = tf.keras.layers.Flatten()(x1)
x6 = tf.keras.layers.Dense(256,activation='relu')(x5)
x7 = tf.keras.layers.Dense(5,activation='softmax')(x6)

model = tf.keras.Model(inputs=(i),outputs=(x7))

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(images,epochs=10)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 6s 795ms/step - loss: 6.0202 - accuracy: 0.1800
# Epoch 2/10
# 4/4 [==============================] - 3s 769ms/step - loss: 2.5131 - accuracy: 0.2600
# Epoch 3/10
# 4/4 [==============================] - 3s 749ms/step - loss: 2.9567 - accuracy: 0.2300
# Epoch 4/10
# 4/4 [==============================] - 4s 1s/step - loss: 1.5094 - accuracy: 0.3500
# Epoch 5/10
# 4/4 [==============================] - 3s 751ms/step - loss: 1.5817 - accuracy: 0.3600
# Epoch 6/10
# 4/4 [==============================] - 3s 771ms/step - loss: 1.4753 - accuracy: 0.3900
# Epoch 7/10
# 4/4 [==============================] - 3s 1s/step - loss: 1.4999 - accuracy: 0.3400
# Epoch 8/10
# 4/4 [==============================] - 3s 761ms/step - loss: 1.2228 - accuracy: 0.5000
# Epoch 9/10
# 4/4 [==============================] - 3s 778ms/step - loss: 1.2531 - accuracy: 0.4400
# Epoch 10/10
# 4/4 [==============================] - 3s 790ms/step - loss: 1.2699 - accuracy: 0.5300
